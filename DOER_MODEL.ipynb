# %% [markdown]
# <a href="https://colab.research.google.com/github/munib-ehman/aura-ai-agent-engine/blob/main/DOER_MODEL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Install simpletransformers**

# %%
# !pip install -q simpletransformers
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.3/43.3 kB 2.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 3.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 330.8/330.8 kB 13.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 132.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 9.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 146.1 MB/s eta 0:00:00
#   Building wheel for seqeval (setup.py) ... done

# %% [markdown]
# **T5 flant model trained on custom dataset**

# %%
import json
import pandas as pd
from simpletransformers.t5 import T5Model, T5Args
import os

# --- Configuration ---
MODEL_TYPE = 't5'
MODEL_NAME = 'google/flan-t5-small'
DATASET_FILE = 'doer_dataset.jsonl'
OUTPUT_DIR = 'outputs/doer_flan_model'
TRAIN_EPOCHS = 12

def create_training_dataframe(file_path):
    """
    Loads the .jsonl file and prepares it for training.
    The target_text is ONLY the workflow array.
    """
    records = []
    print(f"Loading and preparing dataset from '{file_path}'...")
    try:
        with open(file_path, 'r', encoding='utf-8') as f:
            for line in f:
                clean_line = line.strip()
                if clean_line:
                    records.append(json.loads(clean_line))

        print(f"Dataset loaded. Found {len(records)} training examples.")

        data_for_df = []
        for record in records:
            input_data = record.get('input', {})
            output_workflow = record.get('output', {}).get('workflow', [])

            data_for_df.append({
                "prefix": "workflow",
                "input_text": json.dumps(input_data),
                "target_text": json.dumps(output_workflow)
            })

        return pd.DataFrame(data_for_df)

    except FileNotFoundError:
        print(f"Error: Dataset file not found at '{file_path}'")
        return None
    except json.JSONDecodeError as e:
        print(f"Error decoding JSON from the dataset file: {e}")
        return None

def train_doer_model():
    """
    Trains the T5 model on our custom dataset and saves it.
    """
    print("--- Starting Training for Custom 'Doer' Model ---")
    train_df = create_training_dataframe(DATASET_FILE)

    if train_df is None or train_df.empty:
        print("Training cannot proceed without a valid dataset.")
        return

    model_args = T5Args()
    model_args.max_seq_length = 512
    model_args.train_batch_size = 2
    model_args.eval_batch_size = 2
    model_args.num_train_epochs = TRAIN_EPOCHS
    model_args.overwrite_output_dir = True
    model_args.output_dir = OUTPUT_DIR
    model_args.save_steps = -1

    # --- CHANGE 1: ENABLE GPU USAGE ---
    # This tells the model to use the T4 GPU you enabled.
    model_args.use_cuda = True
    model_args.n_gpu = 1

    model_args.learning_rate = 1e-4
    model_args.warmup_steps = 50

    print(f"Initializing '{MODEL_NAME}' model...")
    # --- CHANGE 2: REMOVE use_cuda=False from model creation ---
    # The arguments object (model_args) now handles this.
    model = T5Model(MODEL_TYPE, MODEL_NAME, args=model_args)

    print("\n--- Starting Model Fine-Tuning ---")
    model.train_model(train_df)

    print("\n--- Training Complete ---")
    print(f"Your custom 'Doer' model has been saved to the '{OUTPUT_DIR}' directory.")

# Run the training function
train_doer_model()
# Out:
# --- Starting Training for Custom 'Doer' Model ---
# Loading and preparing dataset from 'doer_dataset.jsonl'...
# Dataset loaded. Found 54 training examples.
# Initializing 'google/flan-t5-small' model...
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/308M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# special_tokens_map.json: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# --- Starting Model Fine-Tuning ---
#   0%|          | 0/54 [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/transformers/tokenization_utils_base.py:4007: UserWarning: `as_target_tokenizer` is deprecated and will be removed in v5 of Transformers. You can tokenize your labels by using the argument `text_target` of the regular `__call__` method (either in the same call as your input texts if you use the same keyword arguments, or in a separate call.
#   warnings.warn(
# Epoch:   0%|          | 0/12 [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/simpletransformers/t5/t5_model.py:528: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = amp.GradScaler()
# Running Epoch 1 of 12:   0%|          | 0/27 [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/simpletransformers/t5/t5_model.py:575: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast():
# Running Epoch 2 of 12:   0%|          | 0/27 [00:00<?, ?it/s]
# Running Epoch 3 of 12:   0%|          | 0/27 [00:00<?, ?it/s]
# Running Epoch 4 of 12:   0%|          | 0/27 [00:00<?, ?it/s]
# Running Epoch 5 of 12:   0%|          | 0/27 [00:00<?, ?it/s]
# Running Epoch 6 of 12:   0%|          | 0/27 [00:00<?, ?it/s]
# Running Epoch 7 of 12:   0%|          | 0/27 [00:00<?, ?it/s]
# Running Epoch 8 of 12:   0%|          | 0/27 [00:00<?, ?it/s]
# Running Epoch 9 of 12:   0%|          | 0/27 [00:00<?, ?it/s]
# Running Epoch 10 of 12:   0%|          | 0/27 [00:00<?, ?it/s]
# Running Epoch 11 of 12:   0%|          | 0/27 [00:00<?, ?it/s]
# Running Epoch 12 of 12:   0%|          | 0/27 [00:00<?, ?it/s]
# --- Training Complete ---
# Your custom 'Doer' model has been saved to the 'outputs/doer_flan_model' directory.

# %% [markdown]
# **Make Zip File of Trained Model**

# %%
# !zip -r doer_model.zip outputs/doer_flan_model/
# Out:
#   adding: outputs/doer_flan_model/ (stored 0%)
#   adding: outputs/doer_flan_model/checkpoint-243-epoch-9/ (stored 0%)
#   adding: outputs/doer_flan_model/checkpoint-243-epoch-9/spiece.model (deflated 48%)
#   adding: outputs/doer_flan_model/checkpoint-243-epoch-9/config.json (deflated 62%)
#   adding: outputs/doer_flan_model/checkpoint-243-epoch-9/added_tokens.json (deflated 83%)
#   adding: outputs/doer_flan_model/checkpoint-243-epoch-9/optimizer.pt (deflated 52%)
#   adding: outputs/doer_flan_model/checkpoint-243-epoch-9/scheduler.pt (deflated 62%)
#   adding: outputs/doer_flan_model/checkpoint-243-epoch-9/generation_config.json (deflated 29%)
#   adding: outputs/doer_flan_model/checkpoint-243-epoch-9/tokenizer_config.json (deflated 94%)
#   adding: outputs/doer_flan_model/checkpoint-243-epoch-9/special_tokens_map.json (deflated 85%)
#   adding: outputs/doer_flan_model/checkpoint-243-epoch-9/model_args.json (deflated 63%)
#   adding: outputs/doer_flan_model/checkpoint-243-epoch-9/model.safetensors (deflated 7%)
#   adding: outputs/doer_flan_model/checkpoint-243-epoch-9/training_args.bin (deflated 54%)
#   adding: outputs/doer_flan_model/checkpoint-189-epoch-7/ (stored 0%)
#   adding: outputs/doer_flan_model/checkpoint-189-epoch-7/spiece.model (deflated 48%)
#   adding: outputs/doer_flan_model/checkpoint-189-epoch-7/config.json (deflated 62%)
#   adding: outputs/doer_flan_model/checkpoint-189-epoch-7/added_tokens.json (deflated 83%)
#   adding: outputs/doer_flan_model/checkpoint-189-epoch-7/optimizer.pt (deflated 52%)
#   adding: outputs/doer_flan_model/checkpoint-189-epoch-7/scheduler.pt (deflated 62%)
#   adding: outputs/doer_flan_model/checkpoint-189-epoch-7/generation_config.json (deflated 29%)
#   adding: outputs/doer_flan_model/checkpoint-189-epoch-7/tokenizer_config.json (deflated 94%)
#   adding: outputs/doer_flan_model/checkpoint-189-epoch-7/special_tokens_map.json (deflated 85%)
#   adding: outputs/doer_flan_model/checkpoint-189-epoch-7/model_args.json (deflated 63%)
#   adding: outputs/doer_flan_model/checkpoint-189-epoch-7/model.safetensors (deflated 7%)
#   adding: outputs/doer_flan_model/checkpoint-189-epoch-7/training_args.bin (deflated 54%)
#   adding: outputs/doer_flan_model/checkpoint-270-epoch-10/ (stored 0%)
#   adding: outputs/doer_flan_model/checkpoint-270-epoch-10/spiece.model (deflated 48%)
#   adding: outputs/doer_flan_model/checkpoint-270-epoch-10/config.json (deflated 62%)
#   adding: outputs/doer_flan_model/checkpoint-270-epoch-10/added_tokens.json (deflated 83%)
#   adding: outputs/doer_flan_model/checkpoint-270-epoch-10/optimizer.pt (deflated 52%)
#   adding: outputs/doer_flan_model/checkpoint-270-epoch-10/scheduler.pt (deflated 62%)
#   adding: outputs/doer_flan_model/checkpoint-270-epoch-10/generation_config.json (deflated 29%)
#   adding: outputs/doer_flan_model/checkpoint-270-epoch-10/tokenizer_config.json (deflated 94%)
#   adding: outputs/doer_flan_model/checkpoint-270-epoch-10/special_tokens_map.json (deflated 85%)
#   adding: outputs/doer_flan_model/checkpoint-270-epoch-10/model_args.json (deflated 63%)
#   adding: outputs/doer_flan_model/checkpoint-270-epoch-10/model.safetensors (deflated 7%)
#   adding: outputs/doer_flan_model/checkpoint-270-epoch-10/training_args.bin (deflated 54%)
#   adding: outputs/doer_flan_model/checkpoint-297-epoch-11/ (stored 0%)
#   adding: outputs/doer_flan_model/checkpoint-297-epoch-11/spiece.model (deflated 48%)
#   adding: outputs/doer_flan_model/checkpoint-297-epoch-11/config.json (deflated 62%)
#   adding: outputs/doer_flan_model/checkpoint-297-epoch-11/added_tokens.json (deflated 83%)
#   adding: outputs/doer_flan_model/checkpoint-297-epoch-11/optimizer.pt (deflated 52%)
#   adding: outputs/doer_flan_model/checkpoint-297-epoch-11/scheduler.pt (deflated 62%)
#   adding: outputs/doer_flan_model/checkpoint-297-epoch-11/generation_config.json (deflated 29%)
#   adding: outputs/doer_flan_model/checkpoint-297-epoch-11/tokenizer_config.json (deflated 94%)
#   adding: outputs/doer_flan_model/checkpoint-297-epoch-11/special_tokens_map.json (deflated 85%)
#   adding: outputs/doer_flan_model/checkpoint-297-epoch-11/model_args.json (deflated 63%)
#   adding: outputs/doer_flan_model/checkpoint-297-epoch-11/model.safetensors (deflated 7%)
#   adding: outputs/doer_flan_model/checkpoint-297-epoch-11/training_args.bin (deflated 54%)
#   adding: outputs/doer_flan_model/spiece.model (deflated 48%)
#   adding: outputs/doer_flan_model/checkpoint-216-epoch-8/ (stored 0%)
#   adding: outputs/doer_flan_model/checkpoint-216-epoch-8/spiece.model (deflated 48%)
#   adding: outputs/doer_flan_model/checkpoint-216-epoch-8/config.json (deflated 62%)
#   adding: outputs/doer_flan_model/checkpoint-216-epoch-8/added_tokens.json (deflated 83%)
#   adding: outputs/doer_flan_model/checkpoint-216-epoch-8/optimizer.pt (deflated 52%)
#   adding: outputs/doer_flan_model/checkpoint-216-epoch-8/scheduler.pt (deflated 62%)
#   adding: outputs/doer_flan_model/checkpoint-216-epoch-8/generation_config.json (deflated 29%)
#   adding: outputs/doer_flan_model/checkpoint-216-epoch-8/tokenizer_config.json (deflated 94%)
#   adding: outputs/doer_flan_model/checkpoint-216-epoch-8/special_tokens_map.json (deflated 85%)
#   adding: outputs/doer_flan_model/checkpoint-216-epoch-8/model_args.json (deflated 63%)
#   adding: outputs/doer_flan_model/checkpoint-216-epoch-8/model.safetensors (deflated 7%)
#   adding: outputs/doer_flan_model/checkpoint-216-epoch-8/training_args.bin (deflated 54%)
#   adding: outputs/doer_flan_model/checkpoint-135-epoch-5/ (stored 0%)
#   adding: outputs/doer_flan_model/checkpoint-135-epoch-5/spiece.model (deflated 48%)
#   adding: outputs/doer_flan_model/checkpoint-135-epoch-5/config.json (deflated 62%)
#   adding: outputs/doer_flan_model/checkpoint-135-epoch-5/added_tokens.json (deflated 83%)
#   adding: outputs/doer_flan_model/checkpoint-135-epoch-5/optimizer.pt (deflated 52%)
#   adding: outputs/doer_flan_model/checkpoint-135-epoch-5/scheduler.pt (deflated 62%)
#   adding: outputs/doer_flan_model/checkpoint-135-epoch-5/generation_config.json (deflated 29%)
#   adding: outputs/doer_flan_model/checkpoint-135-epoch-5/tokenizer_config.json (deflated 94%)
#   adding: outputs/doer_flan_model/checkpoint-135-epoch-5/special_tokens_map.json (deflated 85%)
#   adding: outputs/doer_flan_model/checkpoint-135-epoch-5/model_args.json (deflated 63%)
#   adding: outputs/doer_flan_model/checkpoint-135-epoch-5/model.safetensors (deflated 7%)
#   adding: outputs/doer_flan_model/checkpoint-135-epoch-5/training_args.bin (deflated 54%)
#   adding: outputs/doer_flan_model/config.json (deflated 62%)
#   adding: outputs/doer_flan_model/checkpoint-162-epoch-6/ (stored 0%)
#   adding: outputs/doer_flan_model/checkpoint-162-epoch-6/spiece.model (deflated 48%)
#   adding: outputs/doer_flan_model/checkpoint-162-epoch-6/config.json (deflated 62%)
#   adding: outputs/doer_flan_model/checkpoint-162-epoch-6/added_tokens.json (deflated 83%)
#   adding: outputs/doer_flan_model/checkpoint-162-epoch-6/optimizer.pt (deflated 52%)
#   adding: outputs/doer_flan_model/checkpoint-162-epoch-6/scheduler.pt (deflated 62%)
#   adding: outputs/doer_flan_model/checkpoint-162-epoch-6/generation_config.json (deflated 29%)
#   adding: outputs/doer_flan_model/checkpoint-162-epoch-6/tokenizer_config.json (deflated 94%)
#   adding: outputs/doer_flan_model/checkpoint-162-epoch-6/special_tokens_map.json (deflated 85%)
#   adding: outputs/doer_flan_model/checkpoint-162-epoch-6/model_args.json (deflated 63%)
#   adding: outputs/doer_flan_model/checkpoint-162-epoch-6/model.safetensors (deflated 7%)
#   adding: outputs/doer_flan_model/checkpoint-162-epoch-6/training_args.bin (deflated 54%)
#   adding: outputs/doer_flan_model/added_tokens.json (deflated 83%)
#   adding: outputs/doer_flan_model/generation_config.json (deflated 29%)
#   adding: outputs/doer_flan_model/tokenizer_config.json (deflated 94%)
#   adding: outputs/doer_flan_model/special_tokens_map.json (deflated 85%)
#   adding: outputs/doer_flan_model/checkpoint-81-epoch-3/ (stored 0%)
#   adding: outputs/doer_flan_model/checkpoint-81-epoch-3/spiece.model (deflated 48%)
#   adding: outputs/doer_flan_model/checkpoint-81-epoch-3/config.json (deflated 62%)
#   adding: outputs/doer_flan_model/checkpoint-81-epoch-3/added_tokens.json (deflated 83%)
#   adding: outputs/doer_flan_model/checkpoint-81-epoch-3/optimizer.pt (deflated 52%)
#   adding: outputs/doer_flan_model/checkpoint-81-epoch-3/scheduler.pt (deflated 62%)
#   adding: outputs/doer_flan_model/checkpoint-81-epoch-3/generation_config.json (deflated 29%)
#   adding: outputs/doer_flan_model/checkpoint-81-epoch-3/tokenizer_config.json (deflated 94%)
#   adding: outputs/doer_flan_model/checkpoint-81-epoch-3/special_tokens_map.json (deflated 85%)
#   adding: outputs/doer_flan_model/checkpoint-81-epoch-3/model_args.json (deflated 63%)
#   adding: outputs/doer_flan_model/checkpoint-81-epoch-3/model.safetensors (deflated 7%)
#   adding: outputs/doer_flan_model/checkpoint-81-epoch-3/training_args.bin (deflated 54%)
#   adding: outputs/doer_flan_model/checkpoint-324-epoch-12/ (stored 0%)
#   adding: outputs/doer_flan_model/checkpoint-324-epoch-12/spiece.model (deflated 48%)
#   adding: outputs/doer_flan_model/checkpoint-324-epoch-12/config.json (deflated 62%)
#   adding: outputs/doer_flan_model/checkpoint-324-epoch-12/added_tokens.json (deflated 83%)
#   adding: outputs/doer_flan_model/checkpoint-324-epoch-12/optimizer.pt (deflated 52%)
#   adding: outputs/doer_flan_model/checkpoint-324-epoch-12/scheduler.pt (deflated 62%)
#   adding: outputs/doer_flan_model/checkpoint-324-epoch-12/generation_config.json (deflated 29%)
#   adding: outputs/doer_flan_model/checkpoint-324-epoch-12/tokenizer_config.json (deflated 94%)
#   adding: outputs/doer_flan_model/checkpoint-324-epoch-12/special_tokens_map.json (deflated 85%)
#   adding: outputs/doer_flan_model/checkpoint-324-epoch-12/model_args.json (deflated 63%)
#   adding: outputs/doer_flan_model/checkpoint-324-epoch-12/model.safetensors (deflated 7%)
#   adding: outputs/doer_flan_model/checkpoint-324-epoch-12/training_args.bin (deflated 54%)
#   adding: outputs/doer_flan_model/model_args.json (deflated 63%)
#   adding: outputs/doer_flan_model/model.safetensors (deflated 7%)
#   adding: outputs/doer_flan_model/checkpoint-54-epoch-2/ (stored 0%)
#   adding: outputs/doer_flan_model/checkpoint-54-epoch-2/spiece.model (deflated 48%)
#   adding: outputs/doer_flan_model/checkpoint-54-epoch-2/config.json (deflated 62%)
#   adding: outputs/doer_flan_model/checkpoint-54-epoch-2/added_tokens.json (deflated 83%)
#   adding: outputs/doer_flan_model/checkpoint-54-epoch-2/optimizer.pt (deflated 52%)
#   adding: outputs/doer_flan_model/checkpoint-54-epoch-2/scheduler.pt (deflated 62%)
#   adding: outputs/doer_flan_model/checkpoint-54-epoch-2/generation_config.json (deflated 29%)
#   adding: outputs/doer_flan_model/checkpoint-54-epoch-2/tokenizer_config.json (deflated 94%)
#   adding: outputs/doer_flan_model/checkpoint-54-epoch-2/special_tokens_map.json (deflated 85%)
#   adding: outputs/doer_flan_model/checkpoint-54-epoch-2/model_args.json (deflated 63%)
#   adding: outputs/doer_flan_model/checkpoint-54-epoch-2/model.safetensors (deflated 7%)
#   adding: outputs/doer_flan_model/checkpoint-54-epoch-2/training_args.bin (deflated 54%)
#   adding: outputs/doer_flan_model/checkpoint-108-epoch-4/ (stored 0%)
#   adding: outputs/doer_flan_model/checkpoint-108-epoch-4/spiece.model (deflated 48%)
#   adding: outputs/doer_flan_model/checkpoint-108-epoch-4/config.json (deflated 62%)
#   adding: outputs/doer_flan_model/checkpoint-108-epoch-4/added_tokens.json (deflated 83%)
#   adding: outputs/doer_flan_model/checkpoint-108-epoch-4/optimizer.pt (deflated 52%)
#   adding: outputs/doer_flan_model/checkpoint-108-epoch-4/scheduler.pt (deflated 62%)
#   adding: outputs/doer_flan_model/checkpoint-108-epoch-4/generation_config.json (deflated 29%)
#   adding: outputs/doer_flan_model/checkpoint-108-epoch-4/tokenizer_config.json (deflated 94%)
#   adding: outputs/doer_flan_model/checkpoint-108-epoch-4/special_tokens_map.json (deflated 85%)
#   adding: outputs/doer_flan_model/checkpoint-108-epoch-4/model_args.json (deflated 63%)
#   adding: outputs/doer_flan_model/checkpoint-108-epoch-4/model.safetensors (deflated 7%)
#   adding: outputs/doer_flan_model/checkpoint-108-epoch-4/training_args.bin (deflated 54%)
#   adding: outputs/doer_flan_model/checkpoint-27-epoch-1/ (stored 0%)
#   adding: outputs/doer_flan_model/checkpoint-27-epoch-1/spiece.model (deflated 48%)
#   adding: outputs/doer_flan_model/checkpoint-27-epoch-1/config.json (deflated 62%)
#   adding: outputs/doer_flan_model/checkpoint-27-epoch-1/added_tokens.json (deflated 83%)
#   adding: outputs/doer_flan_model/checkpoint-27-epoch-1/optimizer.pt (deflated 51%)
#   adding: outputs/doer_flan_model/checkpoint-27-epoch-1/scheduler.pt (deflated 61%)
#   adding: outputs/doer_flan_model/checkpoint-27-epoch-1/generation_config.json (deflated 29%)
#   adding: outputs/doer_flan_model/checkpoint-27-epoch-1/tokenizer_config.json (deflated 94%)
#   adding: outputs/doer_flan_model/checkpoint-27-epoch-1/special_tokens_map.json (deflated 85%)
#   adding: outputs/doer_flan_model/checkpoint-27-epoch-1/model_args.json (deflated 63%)
#   adding: outputs/doer_flan_model/checkpoint-27-epoch-1/model.safetensors (deflated 7%)
#   adding: outputs/doer_flan_model/checkpoint-27-epoch-1/training_args.bin (deflated 54%)
#   adding: outputs/doer_flan_model/training_args.bin (deflated 54%)
